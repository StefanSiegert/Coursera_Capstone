# %% [markdown]
# # Week 3 of Data Science Capstone Course
# By Stefan Siegert
#
# ## <b>1st question</b>: Create PANDAS dataframe from Wikipedia table
#
# (for details, comments and markups see other file <i>CapstoneWeek3a</i>)

# %%
import pandas as pd
df_toronto = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
df_toronto_cleaned = df_toronto.dropna().reset_index(drop=True)
df_toronto_cleaned.rename(columns={'Postal Code':'PostalCode'}, inplace=True)
#df_toronto_cleaned
#df_toronto_cleaned.shape

# %% [markdown]
# ## <b>2nd question</b>: Add latitude and longitude to data frame
#
# Let's start with adding 2 more columns to df_toronto_cleaned:

# %%
df_toronto_cleaned.reindex(columns = df_toronto_cleaned.columns.tolist() + ['Latitude','Longitude'])
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# ...

# %% [markdown]
# Now we have to read the geospatial data to a new dataframe 'df_geospatial'. For the following steps it's easier to set the index pointer to the 'Postal Code' column.

# %%
df_geospatial = pd.read_csv('https://cocl.us/Geospatial_data')
df_geospatial.set_index('Postal Code', inplace=True)
df_geospatial
# Out:
#               Latitude  Longitude
# Postal Code
# M1B          43.806686 -79.194353
# M1C          43.784535 -79.160497
# M1E          43.763573 -79.188711
# M1G          43.770992 -79.216917
# M1H          43.773136 -79.239476
# M1J          43.744734 -79.239476
# M1K          43.727929 -79.262029
# M1L          43.711112 -79.284577
# M1M          43.716316 -79.239476
# M1N          43.692657 -79.264848
# M1P          43.757410 -79.273304
# M1R          43.750072 -79.295849
# M1S          43.794200 -79.262029
# M1T          43.781638 -79.304302
# M1V          43.815252 -79.284577
# M1W          43.799525 -79.318389
# M1X          43.836125 -79.205636
# M2H          43.803762 -79.363452
# M2J          43.778517 -79.346556
# M2K          43.786947 -79.385975
# M2L          43.757490 -79.374714
# M2M          43.789053 -79.408493
# M2N          43.770120 -79.408493
# M2P          43.752758 -79.400049
# M2R          43.782736 -79.442259
# M3A          43.753259 -79.329656
# ...

# %% [markdown]
# Now we can iterate through each row of the 'df_toronto_cleaned' data frame and exchange the empty values in columns 'Latitude' and 'Longitude' by the corresponding data from 'df_geospatial'.

# %%
for index, row in df_toronto_cleaned.iterrows():
    df_toronto_cleaned.at[index, 'Latitude'] = df_geospatial.at[row['PostalCode'],'Latitude']
    df_toronto_cleaned.at[index, 'Longitude'] = df_geospatial.at[row['PostalCode'],'Longitude']

# %% [markdown]
# Finally, let's see how 'df_toronto_cleaned' now looks like with the 2 additional columns:

# %%
df_toronto_cleaned
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# ...
